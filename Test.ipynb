# %% [markdown]
# # Test
# ## This notebook tests each function from the Linear library.

# %%
# imports 
import pandas as pd 
import numpy as np
import Linear

# %%
# Add Matrices 
a = pd.DataFrame([[3,2,5],[11,2,8]])
b = pd.DataFrame([[2,1,6],[4,0,4]])
Linear.add(a,b)
# Out:
#     0  1   2
# 0   5  3  11
# 1  15  2  12

# %%
ax = pd.DataFrame([[3,2,5,7],[11,2,8]])
bx = pd.DataFrame([[2,1,6],[4,0,4]])
Linear.add(ax,bx)
# Out:
# These matrices are not the same size. You cannot add them.

# %%
# Multiply Matrices 
c = pd.DataFrame([[1,9],[10,2]])
d = pd.DataFrame([[3,5],[7,4]])
Linear.multiply(c,d)
# Out:
#    Col 1  Col 2
# 0     66     41
# 1     44     58

# %%
cx = pd.DataFrame([[1,9,7],[10,2]])
dx = pd.DataFrame([[3,5],[7,4,1]])
Linear.multiply(cx,dx)
# Out:
# These matrices cannot be multiplied because the number of columns of the first matrix is not equal to the number of rows of the second matrix.

# %%
# 2x2 Determinant
m2 = pd.DataFrame([[1,2],[3,4]])
Linear.det2(m2)
# Out:
# -2

# %%
m2x = pd.DataFrame([[1,2],[3,4,5]])
Linear.det2(m2x)
# Out:
# Not a 2x2 matrix.

# %%
# 3x3 Determinant 
m3 = pd.DataFrame([[3,7,12],[1,4,9],[15,5,0]])
Linear.det3(m3)
# Out:
# 150

# %%
m3x = pd.DataFrame([[3,7,12,1],[1,4,9],[15,5,0]])
Linear.det3(m3x)
# Out:
# Not a 3x3 matrix.

# %%
# 4x4 Determinant 
m4 = pd.DataFrame([[3,7,2,1],[1,4,9,3],[5,5,0,6],[8,3,2,7]]) 
Linear.det4(m4)
# Out:
# -1215

# %%
m4x = pd.DataFrame([[3,7,2,1,4],[1,4,9,3],[5,5,0,6],[8,3,2,7]])
Linear.det4(m4x)
# Out:
# Not a 4x4 matrix.

# %%
# 5x5 Determinant 
m5 = pd.DataFrame([[3,7,12,1,1],[1,4,9,5,13],[2,5,0,6,9],[2,11,8,1,4],[1,2,3,4,5]])
Linear.det5(m5)
# Out:
# -3161

# %%
m5x = pd.DataFrame([[3,7,12,1,1,2],[1,4,9,5,13],[2,5,0,6,9],[2,11,8,1,4],[1,2,3,4,5]])
Linear.det5(m5x)
# Out:
# Not a 5x5 matrix.

# %%
# 6x6 Determinant 
m6 = pd.DataFrame([[3,7,12,1,1,4],[1,4,9,5,13,2],[2,5,0,6,9,14],[2,11,8,1,4,9],[1,2,3,4,5,6],[6,9,12,3,1,0]])
Linear.det6(m6)
# Out:
# 39674

# %%
m6x = pd.DataFrame([[3,7,12,1,1,4,0],[1,4,9,5,13,2],[2,5,0,6,9,14],[2,11,8,1,4,9],[1,2,3,4,5,6],[6,9,12,3,1,0]])
Linear.det6(m6x)
# Out:
# Not a 6x6 matrix.
